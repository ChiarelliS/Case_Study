# %% [markdown]
# # Case study
#
# ## Extract companies' financial informations.

# %% [markdown]
# # Data extraction method
#
# To retrieve the required informations I decided to use edgartools, a Python library with methods that allow to directly send API requests and retrieve the data.
#
# This method allows for faster and easier data retrievial compared to other available methods, allows to directly convert the filings in dataframes, and to extract directly data of interest.
#
# # Data extraction process
#
# After creating an empty dataframe to fill with the retrieved companies' financial informations, I created a for loop to retrieve the data.
#
#
# - using the cik I make an api request using the Company method of edgartools.
# - from here I can access the company information (address, company name, industry description) as well as the 10-k of the latest 5 years.
# - from each 10-k I accessed the financial statement, and extracted the latest occurrence of revenue. I choose to extract the latest occurrence in the financial statement, as sometimes there is just one instance of revenue, sometimes multiple, and when multiple I am going to select the total revenue (which is the latest occurrence of revenue in the statement)
# - once I gathered all the data, I add a new row to the dataframe, with the informations about the company, year of financial statement, revenue, address, industry standard.
#
# # Final step
#
# After retrieving all the informations, some adjustment need to be made to get the correct format for 'geonameen'. Due to some conflict between dependencies, I finished this task in a separate notebook named: 'Cleaning'.

# %%
pip install edgartools
# Out:
# Collecting edgartools
#   Downloading edgartools-3.11.5-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: beautifulsoup4>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from edgartools) (4.13.3)
# Requirement already satisfied: fastcore>=1.5.29 in /usr/local/lib/python3.11/dist-packages (from edgartools) (1.7.29)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from edgartools) (0.28.1)
# Requirement already satisfied: humanize>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from edgartools) (4.11.0)
# Requirement already satisfied: lxml>=4.4 in /usr/local/lib/python3.11/dist-packages (from edgartools) (5.3.1)
# Requirement already satisfied: nest-asyncio>=1.5.1 in /usr/local/lib/python3.11/dist-packages (from edgartools) (1.6.0)
# Requirement already satisfied: orjson>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from edgartools) (3.10.15)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from edgartools) (2.2.2)
# Requirement already satisfied: pyarrow>=14.0.0 in /usr/local/lib/python3.11/dist-packages (from edgartools) (17.0.0)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from edgartools) (2.10.6)
# Collecting rank-bm25>=0.2.1 (from edgartools)
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting rapidfuzz>=3.5.0 (from edgartools)
#   Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: rich>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from edgartools) (13.9.4)
# Collecting stamina>=24.2.0 (from edgartools)
#   Downloading stamina-24.3.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from edgartools) (0.9.0)
# Collecting textdistance>=4.5.0 (from edgartools)
#   Downloading textdistance-4.6.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.11/dist-packages (from edgartools) (4.67.1)
# Collecting unidecode>=1.2.0 (from edgartools)
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.10.0->edgartools) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.10.0->edgartools) (4.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from fastcore>=1.5.29->edgartools) (24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->edgartools) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->edgartools) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->edgartools) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->edgartools) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.0->edgartools) (0.14.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->edgartools) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->edgartools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->edgartools) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->edgartools) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0.0->edgartools) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0.0->edgartools) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.0.0->edgartools) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.0.0->edgartools) (2.18.0)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.11/dist-packages (from stamina>=24.2.0->edgartools) (9.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.0.0->edgartools) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->edgartools) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.0->edgartools) (1.3.1)
# Downloading edgartools-3.11.5-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.9 MB/s eta 0:00:00
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 35.8 MB/s eta 0:00:00
# Downloading stamina-24.3.0-py3-none-any.whl (16 kB)
# Downloading textdistance-4.6.3-py3-none-any.whl (31 kB)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 12.2 MB/s eta 0:00:00
# Installing collected packages: unidecode, textdistance, stamina, rapidfuzz, rank-bm25, edgartools
# Successfully installed edgartools-3.11.5 rank-bm25-0.2.2 rapidfuzz-3.12.1 stamina-24.3.0 textdistance-4.6.3 unidecode-1.3.8

# %%
import pandas as pd
from edgar import *

# %%
us_states = ['AL','AK','AZ','AR','CA','CO','CT','DE','DC','FL','GA',
             'HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA',
             'MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY',
             'NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX',
             'UT','VT','VA','WA','WV','WI','WY']

# %%
set_identity("Sara Chiarelli sarachiarelli@outlook.it") # required to access edgar tools

# %%
filings = get_filings(2024, form= "10-K") # to get the latest companies' filings
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
df = filings.to_pandas() # converting the filings data in a pandas dataframe to access each row

# %%
df1 = df[:1000] # creating a dataframe containing informations about 1000 companies, to use to retrieve companies financial data

# %%
df1 = df1.sort_values(["company", "filing_date"])
df1
# Out:
#        form                       company      cik filing_date  \
# 666    10-K         1 800 FLOWERS COM INC  1084869  2024-09-06
# 812    10-K               3D SYSTEMS CORP   910638  2024-08-13
# 663    10-K   5E Advanced Materials, Inc.  1888654  2024-09-09
# 625    10-K  A-Mark Precious Metals, Inc.  1591588  2024-09-13
# 943    10-K                      AAR CORP     1750  2024-07-19
# ..      ...                           ...      ...         ...
# 225    10-K            i3 Verticals, Inc.  1728688  2024-11-25
# 605    10-K                    iBio, Inc.  1420720  2024-09-20
# 590  10-K/A                    iBio, Inc.  1420720  2024-09-24
# 606    10-K                   iPower Inc.  1830072  2024-09-20
# 921  10-K/A                  iWallet Corp  1498372  2024-07-26
#
#          accession_number
# 666  0001437749-24-028591
# 812  0000910638-24-000030
# 663  0000950170-24-104782
# 625  0000950170-24-106317
# 943  0001104659-24-080890
# ..                    ...
# 225  0001728688-24-000102
# 605  0001420720-24-000038
# 590  0001420720-24-000041
# 606  0001683168-24-006560
# 921  0001393905-24-000270
#
# [1000 rows x 5 columns]

# %%
dfn = pd.DataFrame(columns=["timevalue", "companyname", "industryclassification", "Country", "revenue", "revenue_unit"])

# %%
for i in range(1000):
  try:
    cik = df1.loc[i,"cik"]
    company = Company(f"{cik}")
    name = company.name
    address = str(company.business_address.state_or_country_desc)
    if address in us_states:
      country = "United States"
    else:
      country = address
    sic = company.sic_description
    latest_10k = company.latest("10-K",5) # to get the 5 latest 10k
    for tenk in latest_10k:
      ten = tenk.obj()
      x = ten.financials.income.data
      years = x.columns[0]
      try:
        rev = (((x[x['concept'].str.contains('us-gaap_Revenue', case=False, na=False)]).iloc[-1]).iloc[1]) # to get the latest occurrence of revenue in the filing (sometimes is just one occurence, sometimes is a sum, so i will get the total revenue)
        revenue = abs(int(rev))
      except:
        continue
      unit = "USD"
      new_row = pd.DataFrame({"timevalue": [years], "companyname": [name], "industryclassification": [sic],"Address": [address], "Country":[country], "revenue" : [revenue], "revenue_unit" : [unit]})
      dfn = pd.concat([dfn, new_row], ignore_index=True)
  except:
    continue
# Out:
# WARNING:edgar.core:No XBRL documents found in the filing. Filing(company='NORTH EUROPEAN OIL ROYALTY TRUST', cik=72633, form='10-K', filing_date='2024-12-31', accession_no='0000072633-24-000018')
# WARNING:edgar.core:No XBRL documents found in the filing. Filing(company='

# WARNING:edgar.core:No XBRL documents found in the filing. Filing(company='HeartSciences Inc.', cik=1468492, form='10-K', filing_date='2022-07-29', accession_no='0000950170-22-013513')
# WARNING:edgar.core:No XBRL documents found in the filing. Filing(company='Cannonau Corp.', cik=1410187, form='10-K', filing_date='2022-05-06', accession_no='0001410187-22-000001')
# WARNING:edgar.core:No XBRL documents found in the filing. Filing(company='Cardiff Lexington Corp', cik=811222, form='10-K', filing_date='2022-10-21', accession_no='0001683168-22-007004')
# WARNING:edgar.core:No XBRL documents found in the filing. Filing(company='Cardiff Lexington Corp', cik=811222, form='10-K', filing_date='2022-10-21', accession_no='0001683168-22-007004')
# WARNING:edgar.core:No XBRL documents found in the filing. Filing(company='Next Bridge Hydrocarbons, Inc.', cik=1936756, form='10-K', filing_date='2023-03-31', accession_no='0001199835-23-000181')
# WARNING:edgar.core:No XBRL documents found in the filing. Filing(company='BlueOne Card, Inc.', cik=1496690, form='10-K', filing_date='2011-06-14', accession_no='0001204459-11-001670')
# WARNING:edgar.core:No XBRL documents found in the filing. Filing(company='Indoor Harvest Corp', cik=1572565, form='10-K', filing_date='2024-07-01', accession_no='0001493152-24-025827')
# WARNING:edgar.core:No XBRL documents found in the filing. Filing(company='UNIVERSAL SECURITY INSTRUMENTS INC', cik=102109, form='10-K', filing_date='2021-07-08', accession_no='0001104659-21-090272')
# WARNING:edgar.core:No XBRL documents found in the filing. Filing(company='Bridger Aerospace Group Holdings, Inc.', cik=1941536, form='10-K', filing_date='2023-03-20', accession_no='0001193125-23-074792')
# WARNING:edgar.core:No XBRL documents found in the filing. Filing(company='BlueOne Card, Inc.', cik=1496690, form='10-K', filing_date='2011-06-14', accession_no='0001204459-11-001670')

# %%
len(dfn)
# Out:
# 2995

# %%
dfn
# Out:
#      timevalue                        companyname  \
# 0         2024                 DAILY JOURNAL CORP
# 1         2023                 DAILY JOURNAL CORP
# 2         2024           EXP OldCo Winddown, Inc.
# 3         2023           EXP OldCo Winddown, Inc.
# 4         2022           EXP OldCo Winddown, Inc.
# ...        ...                                ...
# 2990      2021         Global Arena Holding, Inc.
# 2991      2020         Global Arena Holding, Inc.
# 2992      2019         Global Arena Holding, Inc.
# 2993      2023  Optimus Healthcare Services, Inc.
# 2994      2022  Optimus Healthcare Services, Inc.
#
#                                  industryclassification        Country  \
# 0      Newspapers: Publishing or  Publishing & Printing  United States
# 1      Newspapers: Publishing or  Publishing & Printing  United States
# 2                     Retail-Apparel & Accessory Stores  United States
# 3                     Retail-Apparel & Accessory Stores  United States
# 4                     Retail-Apparel & Accessory Stores  United States
# ...                                                 ...            ...
# 2990                      Services-Prepackaged Software  United States
# 2991                      Services-Prepackaged Software  United States
# 2992                      Services-Prepackaged Software  United States
# 2993  Services-Commercial Physical & Biological Rese...  United States
# 2994  Services-Commercial Physical & Biological Rese...  United States
#
#          revenue revenue_unit Address
# 0       67709000          USD      CA
# 1       54009000          USD      CA
# 2     1864182000          USD      OH
# 3     1870296000          USD      OH
# 4     1208374000          USD      OH
# ...          ...          ...     ...
# 2990      641629          USD      NY
# 2991      477773          USD      NY
# 2992      716517          USD      NY
# 2993     1218882          USD      NY
# 2994      827266          USD      NY
#
# [2995 rows x 7 columns]

# %%
dfn.to_excel("Case_Study_to_clean.xlsx")

# %%
from google.colab import files
files.download('Case_Study_to_clean.xlsx')
