# %% [markdown]
# # Final step
#
# This is a brief program to convert the country name format and standardize it using the 'dataprep' Python Library.
# This is in a separate notebook because of conflicting dependencies between edgartools and dataprep.
#
# # Final dataframe
#
# After converting the country format, and adjusting the dataframe structure to match the original one, I proceeded to concatenate the two dataframe, and downloading the final 'output' dataframe.

# %%
pip install dataprep

# %%
pip install markupsafe==2.0.1

# %%
from dataprep.clean import clean_country
import pandas as pd

# %%
df = pd.read_excel("/content/Case_Study_to_clean.xlsx",index_col=0)

# %%
df = clean_country(df, "Country")
# Out:
# Country Cleaning Report:
# 	80 values cleaned (2.67%)
# Result contains 2995 (100.0%) values in the correct format and 0 null values (0.0%)

# %%
df
# Out:
#      timevalue                        companyname  \
# 0         2024                 DAILY JOURNAL CORP
# 1         2023                 DAILY JOURNAL CORP
# 2         2024           EXP OldCo Winddown, Inc.
# 3         2023           EXP OldCo Winddown, Inc.
# 4         2022           EXP OldCo Winddown, Inc.
# ...        ...                                ...
# 2990      2021         Global Arena Holding, Inc.
# 2991      2020         Global Arena Holding, Inc.
# 2992      2019         Global Arena Holding, Inc.
# 2993      2023  Optimus Healthcare Services, Inc.
# 2994      2022  Optimus Healthcare Services, Inc.
#
#                                  industryclassification        Country  \
# 0      Newspapers: Publishing or  Publishing & Printing  United States
# 1      Newspapers: Publishing or  Publishing & Printing  United States
# 2                     Retail-Apparel & Accessory Stores  United States
# 3                     Retail-Apparel & Accessory Stores  United States
# ...

# %%
df['geonameen'] = df['Country_clean']

# %%
df2 = df.drop(['Country','Country_clean','Address'],axis=1)

# %%
df2
# Out:
#      timevalue                        companyname  \
# 0         2024                 DAILY JOURNAL CORP
# 1         2023                 DAILY JOURNAL CORP
# 2         2024           EXP OldCo Winddown, Inc.
# 3         2023           EXP OldCo Winddown, Inc.
# 4         2022           EXP OldCo Winddown, Inc.
# ...        ...                                ...
# 2990      2021         Global Arena Holding, Inc.
# 2991      2020         Global Arena Holding, Inc.
# 2992      2019         Global Arena Holding, Inc.
# 2993      2023  Optimus Healthcare Services, Inc.
# 2994      2022  Optimus Healthcare Services, Inc.
#
#                                  industryclassification     revenue  \
# 0      Newspapers: Publishing or  Publishing & Printing    67709000
# 1      Newspapers: Publishing or  Publishing & Printing    54009000
# 2                     Retail-Apparel & Accessory Stores  1864182000
# 3                     Retail-Apparel & Accessory Stores  1870296000
# ...

# %%
len(df2['companyname'].unique())
# Out:
# 694

# %%
excel_table = pd.read_excel("/content/CaseStudy_Sourcing_sample.xlsx")

# %%
concatenated_df = pd.concat([excel_table, df2])
concatenated_df
# Out:
#      timevalue                        companyname  \
# 0         2022                       &Do Holdings
# 1         2021                       &Do Holdings
# 2         2020                       &Do Holdings
# 3         2019                       &Do Holdings
# 4         2018                       &Do Holdings
# ...        ...                                ...
# 2990      2021         Global Arena Holding, Inc.
# 2991      2020         Global Arena Holding, Inc.
# 2992      2019         Global Arena Holding, Inc.
# 2993      2023  Optimus Healthcare Services, Inc.
# 2994      2022  Optimus Healthcare Services, Inc.
#
#                                  industryclassification      geonameen  \
# 0                                         Manufacturing          Japan
# 1                                         Manufacturing          Japan
# 2                                         Manufacturing          Japan
# 3                                         Manufacturing          Japan
# ...

# %%
concatenated_df.to_excel("output.xlsx", index = None)

# %%
from google.colab import files
files.download('output.xlsx')
