# %% [markdown]
# # Final step
#
# This is a brief program to convert the country name format and standardize it using the 'dataprep' Python Library.
# This is in a separate notebook because of conflicting dependencies between edgartools and dataprep.
#
# # Final dataframe
#
# After converting the country format, and adjusting the dataframe structure to match the original one, I proceeded to concatenate the two dataframe, and downloading the final 'output' dataframe.

# %%
pip install dataprep

# %%
pip install markupsafe==2.0.1

# %%
from dataprep.clean import clean_country
import pandas as pd

# %%
df = pd.read_excel("/content/Case_Study_to_clean.xlsx",index_col=0)

# %%
df2 = clean_country(df, "Country")
# Out:
# Country Cleaning Report:
# 	75 values cleaned (1.46%)
# Result contains 5130 (99.71%) values in the correct format and 15 null values (0.29%)

# %%
df2['geonameen'] = df2['Country_clean']

# %%
df2 = df2.drop(['Country','Country_clean'],axis=1)

# %%
df2
# Out:
#       timevalue         companyname  \
# 0          2023  DAILY JOURNAL CORP
# 1          2022  DAILY JOURNAL CORP
# 2          2021  DAILY JOURNAL CORP
# 3          2020  DAILY JOURNAL CORP
# 4          2019  DAILY JOURNAL CORP
# ...         ...                 ...
# 5140       2023       FOSTER L B CO
# 5141       2022       FOSTER L B CO
# 5142       2021       FOSTER L B CO
# 5143       2020       FOSTER L B CO
# 5144       2019       FOSTER L B CO
#
#                                 industryclassification  revenue revenue_unit  \
# 0     Newspapers: Publishing or  Publishing & Printing   610461          USD
# 1     Newspapers: Publishing or  Publishing & Printing   589035          USD
# 2     Newspapers: Publishing or  Publishing & Printing   754334          USD
# 3     Newspapers: Publishing or  Publishing & Printing  1604606          USD
# 4     Newspapers: Publishing or  Publishing & Printing  1384193          USD
# ...                                                ...      ...          ...
# 5140       Wholesale-Metals Service Centers & of fices   610461          USD
# 5141       Wholesale-Metals Service Centers & of fices   589035          USD
# 5142       Wholesale-Metals Service Centers & of fices   754334          USD
# 5143       Wholesale-Metals Service Centers & of fices  1604606          USD
# 5144       Wholesale-Metals Service Centers & of fices  1384193          USD
#
#           geonameen
# 0     United States
# 1     United States
# 2     United States
# 3     United States
# 4     United States
# ...             ...
# 5140  United States
# 5141  United States
# 5142  United States
# 5143  United States
# 5144  United States
#
# [5145 rows x 6 columns]

# %%
len(df2['companyname'].unique())
# Out:
# 1000

# %%
excel_table = pd.read_excel("/content/CaseStudy_Sourcing_sample.xlsx")

# %%
concatenated_df = pd.concat([excel_table, df2])
concatenated_df
# Out:
#       timevalue    companyname                       industryclassification  \
# 0          2022   &Do Holdings                                Manufacturing
# 1          2021   &Do Holdings                                Manufacturing
# 2          2020   &Do Holdings                                Manufacturing
# 3          2019   &Do Holdings                                Manufacturing
# 4          2018   &Do Holdings                                Manufacturing
# ...         ...            ...                                          ...
# 5140       2023  FOSTER L B CO  Wholesale-Metals Service Centers & of fices
# 5141       2022  FOSTER L B CO  Wholesale-Metals Service Centers & of fices
# 5142       2021  FOSTER L B CO  Wholesale-Metals Service Centers & of fices
# 5143       2020  FOSTER L B CO  Wholesale-Metals Service Centers & of fices
# 5144       2019  FOSTER L B CO  Wholesale-Metals Service Centers & of fices
#
#           geonameen   revenue revenue_unit
# 0             Japan  56486691          USD
# 1             Japan  20546835          USD
# 2             Japan  40263310          USD
# 3             Japan  53111324          USD
# 4             Japan  33582744          USD
# ...             ...       ...          ...
# 5140  United States    610461          USD
# 5141  United States    589035          USD
# 5142  United States    754334          USD
# 5143  United States   1604606          USD
# 5144  United States   1384193          USD
#
# [5169 rows x 6 columns]

# %%
concatenated_df.to_excel("output.xlsx", index = None)

# %%
from google.colab import files
files.download('output.xlsx')
